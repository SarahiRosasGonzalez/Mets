# %% [markdown]
# <a href="https://colab.research.google.com/github/SarahiRosasGonzalez/Mets/blob/main/Copia_de_An%C3%A1lisis_METS_OPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
drive.mount('/content/drive')

# Specify the file path, correcting the duplicate path
file_path = '/content/drive/MyDrive/s20-10-data/Metastasis/base-de-datos-mets-opt.csv'

# Cargar dataset
df = pd.read_csv(file_path, encoding='latin-1')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Sección nueva

# %%
# Vista previa de las dimensiones de dataaset e identificar inconsistencias
print('Forma:', df.shape)
print('\
Columas:', df.columns.tolist())
print('\
Valores nulos:')
print(df.isnull().sum())
print('\
duplicados:', df.duplicates().sum() if hasattr(df, 'duplicates') else len(df[df.duplicated()]))
print('\
Muestra de los datos:')
print(df.head())
# Out:
# Forma: (466, 18)
# Columas: ['EXPEDIENTE', 'NOMBRE', 'EDAD', 'SEXO', 'TUMOR PRIMARIO', 'SUBTIPO HISTOLOGICO', 'PERFIL MOLECULAR', 'TAMAÑO (mm)', 'LOCALIZACIÓN', 'CIRUGIA PREVIA', 'SRS', 'DOSIS (Gy)', 'TECNICA ', 'TRATAMIENTO SISTEMICO', 'RESPUESTA (CRITERIOS RANO)', '1ER ESTUDIO DE SEGUIMIENTO', 'RC', 'RADIONECROSIS']
# Valores nulos:
# EXPEDIENTE                    244
# NOMBRE                        244
# EDAD                            1
# SEXO                            1
# TUMOR PRIMARIO                  1
# SUBTIPO HISTOLOGICO            20
# PERFIL MOLECULAR              176
# TAMAÑO (mm)                     1
# LOCALIZACIÓN                    0
# CIRUGIA PREVIA                  0
# SRS                             1
# DOSIS (Gy)                      0
# TECNICA                         0
# TRATAMIENTO SISTEMICO          70
# RESPUESTA (CRITERIOS RANO)      0
# 1ER ESTUDIO DE SEGUIMIENTO    336
# RC                            121
# RADIONECROSIS                   0
# dtype: int64
# duplicados: 8
# Muestra de los datos:
#    EXPEDIENTE                            NOMBRE  EDAD SEXO  TUMOR PRIMARIO  \
# 0    209406.0       ANA LAURA SANTANA RODRIGUEZ  55.0    F  CÁNCER DE MAMA
# 1    225523.0  HERNANDEZ PEREZ FRANCISCO JAVIER  56.0    M    CÁNCER RENAL
# 2    225523.0  HERNANDEZ PEREZ FRANCISCO JAVIER  56.0    M    CÁNCER RENAL
# 3    225523.0  HERNANDEZ PEREZ FRANCISCO JAVIER  56.0    M    CÁNCER RENAL
# 4    225523.0  HERNANDEZ PEREZ FRANCISCO JAVIER  56.0    M    CÁNCER RENAL
#
#             SUBTIPO HISTOLOGICO PERFIL MOLECULAR TAMAÑO (mm)  LOCALIZACIÓN  \
# 0  CARCINOMA DUCTAL INFILTRANTE  TRIPLE NEGATIVO          26  PARIETAL IZQ
# 1   CARCINOMA DE CÉLULAS CLARAS              NaN          17   FRONTAL DER
# 2   CARCINOMA DE CÉLULAS CLARAS              NaN        4.55   FRONTAL DER
# 3   CARCINOMA DE CÉLULAS CLARAS              NaN        3.44      CEREBELO
# 4   CARCINOMA DE CÉLULAS CLARAS              NaN         4.9      CEREBELO
#
#   CIRUGIA PREVIA SRS  DOSIS (Gy) TECNICA  TRATAMIENTO SISTEMICO  \
# 0             SI  DU          16     VMAT          CAPECITABINE
# 1             NO  DU          20     VMAT             SORAFENIB
# 2             NO  DU          22     VMAT             PAZOPANIB
# 3             NO  DU          22     VMAT             PAZOPANIB
# 4             NO  DU          22     VMAT             PAZOPANIB
#
#   RESPUESTA (CRITERIOS RANO) 1ER ESTUDIO DE SEGUIMIENTO               RC  \
# 0        RESPUESTA COMPLETA                     8 MESES               RC
# 1                    ESTABLE                    8 MESES   NADIR A 6 AÑOS
# 2          RESPUESTA PARCIAL                    5 MESES  NADIR 36 MESES
# 3          RESPUESTA PARCIAL                    5 MESES     RC 12 MESES
# 4                    ESTABLE                    5 MESES  NADIR 60 MESES
#
#   RADIONECROSIS
# 0  ASINTOMATICA
# 1  ASINTOMATICA
# 2   SINTOMATICA
# 3  ASINTOMATICA
# 4  ASINTOMATICA

# %% [markdown]
# Se muestra una cantidad significativa de valores nulos en varias columnas (EXPEDIENTE, NOMBRE, PERFIL MOLECULAR, TRATAMIENTO SISTEMICO, 1ER ESTUDIO DE SEGUIMIENTO y RC) y 8 filas duplicadas.

# %% [markdown]
# Primero, para un próximo análisis de tipo A/B testing, nos aseguraremos de que cada valor de la comlumna "EXPEDIENTE" sea único, asignándole un único ID.

# %%
# Asegurarse de que los IDs en la columna 'EXPEDIENTE' sean únicos
# Si existen duplicados, añadir un sufijo para hacerlos únicos
df['EXPEDIENTE'] = df['EXPEDIENTE'].astype(str)  # Convertir a string para su manipulación
df['EXPEDIENTE'] = df.groupby('EXPEDIENTE').cumcount().astype(str) + '_' + df['EXPEDIENTE']

# Verificar cambios
print('Updated EXPEDIENTE column with unique IDs:')
print(df['EXPEDIENTE'].head())
# Out:
# Updated EXPEDIENTE column with unique IDs:
# 0    0_209406.0
# 1    0_225523.0
# 2    1_225523.0
# 3    2_225523.0
# 4    3_225523.0
# Name: EXPEDIENTE, dtype: object

# %%
# Crear una columna de ID única para mejor identificacion de tumores al diferenciarlo de los pacientes con numero de expediente
df['ID'] = range(1, len(df) + 1)

# Reordenar columnas para que 'ID' esté al principio
cols = ['ID'] + [col for col in df.columns if col != 'ID']
df = df[cols]

# %%
# Manejo de datos duplicados eliminándolos
df_cleaned = df.drop('NOMBRE', axis=1)
df_cleaned = df_cleaned.drop_duplicates()

# Rellene los valores nulos de las columnas numéricas con su mediana y las columnas categóricas con 'Desconocido'
for col in df_cleaned.columns:
    if df_cleaned[col].dtype in ['float64', 'int64']:
        df_cleaned[col].fillna(df_cleaned[col].median(), inplace=True)
    else:
        df_cleaned[col].fillna('Unknown', inplace=True)

# Verificar la limpieza de los datos
print("Forma después de la limpieza:", df_cleaned.shape)
print("\
Valores nulos después de la limpieza:")
print(df_cleaned.isnull().sum())
print("\
Muestra de los datos después de la limpieza:")
print(df_cleaned.head())
# Out:
# Forma después de la limpieza: (466, 18)
# Valores nulos después de la limpieza:
# ID                            0
# EXPEDIENTE                    0
# EDAD                          0
# SEXO                          0
# TUMOR PRIMARIO                0
# SUBTIPO HISTOLOGICO           0
# PERFIL MOLECULAR              0
# TAMAÑO (mm)                   0
# LOCALIZACIÓN                  0
# CIRUGIA PREVIA                0
# SRS                           0
# DOSIS (Gy)                    0
# TECNICA                       0
# TRATAMIENTO SISTEMICO         0
# RESPUESTA (CRITERIOS RANO)    0
# 1ER ESTUDIO DE SEGUIMIENTO    0
# RC                            0
# RADIONECROSIS                 0
# dtype: int64
# Muestra de los datos después de la limpieza:
#    ID  EXPEDIENTE  EDAD SEXO  TUMOR PRIMARIO           SUBTIPO HISTOLOGICO  \
# 0   1  0_209406.0  55.0    F  CÁNCER DE MAMA  CARCINOMA DUCTAL INFILTRANTE
# 1   2  0_225523.0  56.0    M    CÁNCER RENAL   CARCINOMA DE CÉLULAS CLARAS
# 2   3  1_225523.0  56.0    M    CÁNCER RENAL   CARCINOMA DE CÉLULAS CLARAS
# 3   4  2_225523.0  56.0    M    CÁNCER RENAL   CARCINOMA DE CÉLULAS CLARAS
# 4   5  3_225523.0  56.0    M    CÁNCER RENAL   CARCINOMA DE CÉLULAS CLARAS
#
#   PERFIL MOLECULAR TAMAÑO (mm)  LOCALIZACIÓN CIRUGIA PREVIA SRS  DOSIS (Gy)  \
# 0  TRIPLE NEGATIVO          26  PARIETAL IZQ             SI  DU          16
# 1          Unknown          17   FRONTAL DER             NO  DU          20
# 2          Unknown        4.55   FRONTAL DER             NO  DU          22
# 3          Unknown        3.44      CEREBELO             NO  DU          22
# 4          Unknown         4.9      CEREBELO             NO  DU          22
#
#   TECNICA  TRATAMIENTO SISTEMICO RESPUESTA (CRITERIOS RANO)  \
# 0     VMAT          CAPECITABINE        RESPUESTA COMPLETA
# 1     VMAT             SORAFENIB                    ESTABLE
# 2     VMAT             PAZOPANIB          RESPUESTA PARCIAL
# 3     VMAT             PAZOPANIB          RESPUESTA PARCIAL
# 4     VMAT             PAZOPANIB                    ESTABLE
#
#   1ER ESTUDIO DE SEGUIMIENTO               RC RADIONECROSIS
# 0                    8 MESES               RC  ASINTOMATICA
# 1                    8 MESES   NADIR A 6 AÑOS  ASINTOMATICA
# 2                    5 MESES  NADIR 36 MESES    SINTOMATICA
# 3                    5 MESES     RC 12 MESES   ASINTOMATICA
# 4                    5 MESES  NADIR 60 MESES   ASINTOMATICA
# <ipython-input-13-1752866d96ea>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cleaned[col].fillna(df_cleaned[col].median(), inplace=True)
# <ipython-input-13-1752866d96ea>:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_cleaned[col].fillna('Unknown', inplace=True)

# %% [markdown]
# De la columna "RESPUESTA (CRITERIOS RANO)" construir una variable binaria , es decir, si la respuesta es ESTABLE o PROGRESIÓN se asignará el valor 0 y al resto el valor 1

# %%
print("Valores únicos en RESPUESTA (CRITERIOS RANO):")
print(df_cleaned['RESPUESTA (CRITERIOS RANO)'].unique())
# Out:
# Valores únicos en RESPUESTA (CRITERIOS RANO):
# ['RESPUESTA COMPLETA ' 'ESTABLE' 'RESPUESTA PARCIAL' 'RESPUESTA COMPLETA'
#  'PROGRESIÓN' 'ESTABLE ' 'PROGRESION']

# %%
df_cleaned['RESPUESTA (CRITERIOS RANO)'] = df_cleaned['RESPUESTA (CRITERIOS RANO)'].replace({
    'RESPUESTA COMPLETA ': 'RESPUESTA COMPLETA',
    'ESTABLE ': 'ESTABLE',
    'PROGRESION': 'PROGRESIÓN'
}, regex=False)

# %%
# Asignar a la columna 'RESPUESTA (CRITERIOS RANO)' valor binario
def map_response(value):
    if value.strip().upper() in ['ESTABLE', 'PROGRESIÓN']:
        return 0
    else:
        return 1

df_cleaned['RESPUESTA_BINARIA'] = df_cleaned['RESPUESTA (CRITERIOS RANO)'].apply(map_response)

# Verificar cambios
print('Columna RESPUESTA_BINARIA actualizada:')
print(df_cleaned[['RESPUESTA (CRITERIOS RANO)', 'RESPUESTA_BINARIA']].head())
# Out:
# Columna RESPUESTA_BINARIA actualizada:
#   RESPUESTA (CRITERIOS RANO)  RESPUESTA_BINARIA
# 0         RESPUESTA COMPLETA                  1
# 1                    ESTABLE                  0
# 2          RESPUESTA PARCIAL                  1
# 3          RESPUESTA PARCIAL                  1
# 4                    ESTABLE                  0

# %% [markdown]
# Realizar una prueba chi-cuadrado. Analizar la relación entre “CIRUGÍA PREVIA” (variable categórica) y “RESPUESTA_BINARIA” (resultado binario) para determinar si la cirugía previa impacta significativamente en la respuesta binaria.

# %%
print("Valores únicos en CIRUGIA PREVIA:")
print(df['CIRUGIA PREVIA'].unique())
# Out:
# Valores únicos en CIRUGIA PREVIA:
# ['SI' 'NO' 'NO ']

# %%
df_cleaned['CIRUGIA PREVIA'] = df_cleaned['CIRUGIA PREVIA'].str.strip()

# %%
# Agrupar datos por 'CIRUGIA PREVIA' y calcular la media de 'RESPUESTA_BINARIA'
grouped_data = df_cleaned.groupby('CIRUGIA PREVIA')['RESPUESTA_BINARIA'].mean()

# Realizar prueba de chi-cuadrado para evaluar la independencia
contingency_table = pd.crosstab(df_cleaned['CIRUGIA PREVIA'], df_cleaned['RESPUESTA_BINARIA'])
chi2, p, dof, expected = stats.chi2_contingency(contingency_table)

# Visualizar resultados
sns.barplot(x=grouped_data.index, y=grouped_data.values)
plt.title('Tasa de RESPUESTA por CIRUGIA PREVIA')
plt.xlabel('CIRUGIA PREVIA')
plt.ylabel('Tasa de RESPUESTA')
plt.show()

#Mostrar resultados
print('Resultado del test Chi-squared:')
print('Chi2:', chi2)
print('p-value:', p)
print('Grados de libertad:', dof)
print('Frecuencias esperadas:')
print(expected)
# Out:
# Resultado del test Chi-squared:
# Chi2: 0.44244832888963564
# p-value: 0.5059431123526137
# Grados de libertad: 1
# Frecuencias esperadas:
# [[177.76824034 258.23175966]
#  [ 12.23175966  17.76824034]]

# %% [markdown]
# Se concluye a partir de los resultados de la prueba de chi-cuadrado (valor p = 0.5059> 0,05), no hay diferencia estadísticamente significativa en las tasas de respuesta entre pacientes con y sin cirugía previa. La visualización muestra proporciones de respuesta similares entre ambos grupos.

# %% [markdown]
# Para una siguiente prueba A/B entre “TRATAMIENTO SISTEMICO” y “RESPUESTA_BINARIA”, se analizará la relación entre estas variables mediante una prueba de chi-cuadrado. Visualizar los resultados.

# %%
print("Valores únicos en TRATAMIENTO SISTEMICO:")
print(df['TRATAMIENTO SISTEMICO'].unique())
# Out:
# Valores únicos en TRATAMIENTO SISTEMICO:
# ['CAPECITABINE' 'SORAFENIB' 'PAZOPANIB' 'NIVOLUMAB' 'TRASTUZUMAB'
#  'TRASTUZUMAB + VINORELVINE' nan 'BEVACIZUMAB' 'VINORELBINA'
#  'VINERALBINE + TRASTUZUMAB' 'GEFITINIB' 'CARBOPLATINO/PACLITAXEL'
#  'TEMOZOLOMIDA' 'OXALIPLATINO + CAPECITABINA' 'FULVESTRANT/PALBOCICLIB'
#  'CLOROQUINA' 'NIVOLUMAB + CABOZANTINIB' 'IPILIMUMAB' 'PEMBROLIZUMAB'
#  '5 CICLOS NO ESPECIFICA' 'CAPECITABINE + FULVESTRANT'
#  'CARBOPLATINO + PACLITAXEL' 'AFATINIB' 'CAPECITABINE + TRASTUZUMAB'
#  'TRASTUZUMAB/ETAMSILATO' 'NIVOLUMAB + IPILIMUMAB' 'CISPLATINO/ETOPOSIDO'
#  'TRASTUZUMAB/DOCETAXEL' 'CAPECITABINE + TRASTUZUMAB + EXEMESTANO'
#  'ETAMSINA + TRASTUZUMAB + DENOSUMAB' 'ETOPÓSIDO' 'ALETINIB' 'ALEKTINIB'
#  'I131' 'TRASTUZUMAB + LAPATINIB' 'DOCETAXEL + CARBOPLATINO + TRASTUZUMAB'
#  'TRASTUZUMAB + ANASTROZOL + GOSERELINE'
#  'PACLITAXEL + TRASTOZUMAB + TAMOXIFENO' 'PEMETREXED + CARBOPLATINO'
#  'TAMOXIFENO' 'LAPATINIB + TRASTUZUMAB' 'PACLITAXEL' 'SUNITINIB'
#  'CARBOPLATINO + PEMETREXED' 'PACLITAXEL + CARBOPLATINO' 'DURVALUMAB'
#  'TRASTUZUMAB + PERTUZUMAB' 'TRASTUZUMAB + DOCETAXEL'
#  'TRASTUZUMAB + CAPECITABINE' 'ETOPÓSIDO + CARBOPLATINO'
#  'TRASTUZUMAB + CARBOPLATINO' 'DOCETAXEL + PACLITAXEL' 'CARBOPLATINO'
#  'PACLITAXEL+ CARBOPLATINO' 'BEVACIZUMAB + PEMETREXED' 'CABOZATINIB'
#  'DOCETAXEL + TRASTUZUMAB'
#  'PANITUMUMAB + FLUOROURACIL. LEUCOVORIN. IRINITECAN']

# %%
# Agrupar data por 'TRATAMIENTO SISTEMICO' y calcular la media de 'RESPUESTA_BINARIA'
grouped_data = df_cleaned.groupby('TRATAMIENTO SISTEMICO')['RESPUESTA_BINARIA'].mean()

# Realizar prueba chi-cuadrado
contingency_table = pd.crosstab(df_cleaned['TRATAMIENTO SISTEMICO'], df_cleaned['RESPUESTA_BINARIA'])
chi2, p_value, dof, expected = stats.chi2_contingency(contingency_table)


print('\nResultados del Test Chi-cuadrado:')
print(f'Estadístico Chi2: {chi2:.4f}')
print(f'Valor p: {p_value:.4f}')
print('\nTabla de contingencia:')
print(contingency_table)

# Crear gráfico de barras apiladas
colors = ['lightcoral', 'lightgreen']  # Define los colores para las respuestas 0 y 1
grouped_data.plot(kind='bar', stacked=True, color=colors, figsize=(10, 6))

# Personalizar el gráfico
plt.title('Relación entre Tratamiento Sistémico y Respuesta')
plt.xlabel('Tratamiento Sistémico')
plt.ylabel('Proporción de Respuestas')
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.legend(labels=['0 (Estable/Progresión)', '1 (Respuesta parcial/completa)'])
plt.tight_layout()

# Mostrar el gráfico
plt.show()
# Out:
# Resultados del Test Chi-cuadrado:
# Estadístico Chi2: 133.2487
# Valor p: 0.0000
#
# Tabla de contingencia:
# RESPUESTA_BINARIA                                    0   1
# TRATAMIENTO SISTEMICO
# 5 CICLOS NO ESPECIFICA                               3   0
# AFATINIB                                             4   4
# ALEKTINIB                                            0   1
# ALETINIB                                             3  11
# BEVACIZUMAB                                          1   1
# BEVACIZUMAB + PEMETREXED                             7  13
# CABOZATINIB                                          0   1
# CAPECITABINE                                        27   8
# CAPECITABINE + FULVESTRANT                           1   2
# CAPECITABINE + TRASTUZUMAB                           3  13
# CAPECITABINE + TRASTUZUMAB + EXEMESTANO              0   5
# CARBOPLATINO                                         1   4
# CARBOPLATINO + PACLITAXEL                            3   9
# CARBOPLATINO + PEMETREXED                            1   6
# CARBOPLATINO/PACLITAXEL                              6   0
# CISPLATINO/ETOPOSIDO                                 3  13
# CLOROQUINA                                           1   3
# DOCETAXEL + CARBOPLATINO + TRASTUZUMAB               0   1
# DOCETAXEL + PACLITAXEL                               1   2
# DOCETAXEL + TRASTUZUMAB                              2   1
# DURVALUMAB                                           5   4
# ETAMSINA + TRASTUZUMAB + DENOSUMAB                   2   4
# ETOPÓSIDO                                            0   1
# ETOPÓSIDO + CARBOPLATINO                             0   1
# FULVESTRANT/PALBOCICLIB                              1   0
# GEFITINIB                                            8   2
# I131                                                 1   2
# IPILIMUMAB                                           1   0
# LAPATINIB + TRASTUZUMAB                              2   1
# NIVOLUMAB                                            1   1
# NIVOLUMAB + CABOZANTINIB                             0   1
# NIVOLUMAB + IPILIMUMAB                               0   2
# OXALIPLATINO + CAPECITABINA                          1   0
# PACLITAXEL                                           0   1
# PACLITAXEL + CARBOPLATINO                            0   1
# PACLITAXEL + TRASTOZUMAB + TAMOXIFENO                4   0
# PACLITAXEL+ CARBOPLATINO                             2   6
# PANITUMUMAB + FLUOROURACIL. LEUCOVORIN. IRINITECAN   0   2
# PAZOPANIB                                            3   3
# PEMBROLIZUMAB                                        5   8
# PEMETREXED + CARBOPLATINO                            6  26
# SORAFENIB                                            1   0
# SUNITINIB                                            0   1
# TAMOXIFENO                                           0   2
# TEMOZOLOMIDA                                         4   0
# TRASTUZUMAB                                         19  22
# TRASTUZUMAB + ANASTROZOL + GOSERELINE                1   0
# TRASTUZUMAB + CAPECITABINE                           0   5
# TRASTUZUMAB + CARBOPLATINO                           2   1
# TRASTUZUMAB + DOCETAXEL                              3   1
# TRASTUZUMAB + LAPATINIB                              2   7
# TRASTUZUMAB + PERTUZUMAB                             3   3
# TRASTUZUMAB + VINORELVINE                            1   0
# TRASTUZUMAB/DOCETAXEL                                9   3
# TRASTUZUMAB/ETAMSILATO                               9   1
# Unknown                                             20  50
# VINERALBINE + TRASTUZUMAB                            3   0
# VINORELBINA                                          4  16

# %% [markdown]
# Los resultados de la prueba de chi-cuadrado indican una relación estadísticamente significativa entre “TRATAMIENTO SISTEMICO” y “RESPUESTA_BINARIA” (valor p < 0,05).

# %% [markdown]
# Relación entre las columnas "TUMOR PRIMARIO" y "LOCALIZACIÓN"

# %%
print("Valores únicos en TUMOR PRIMARIO:")
print(df['TUMOR PRIMARIO'].unique())
# Out:
# Valores únicos en TUMOR PRIMARIO:
# ['CÁNCER DE MAMA' 'CÁNCER RENAL' 'CÁNCER DE PULMÓN' 'CÁNCER DE COLON'
#  'CÁNCER DE ENDOMETRIO' 'CÁNCER CERVICOUTERINO' 'CÁNCER DE TIROIDES'
#  'TUMOR NEUROECTODÉRMICO' 'MELANOMA' 'CÁNCER TESTICULAR'
#  'CÁNCER DE OVARIO' 'CÁNCER DE PRÓSTATA' 'TUMOR NEUROENDOCRINO' nan
#  'CÁNCER RENAL ' 'CÁNCER DE ESOFAGO']

# %%
df_cleaned['TUMOR PRIMARIO'] = df_cleaned['TUMOR PRIMARIO'].replace({'CÁNCER RENAL ': 'CÁNCER RENAL'}, regex=False)

# %%
print("Valores únicos en LOCALIZACIÓN:")
print(df['LOCALIZACIÓN'].unique())
# Out:
# Valores únicos en LOCALIZACIÓN:
# ['PARIETAL IZQ' 'FRONTAL DER' 'CEREBELO' 'FRONTAL IZQ' 'PARIETAL DER'
#  'ÓRBITA IZQ' 'TENTORIAL' 'MESENCÉFALO' 'TEMPORAL IZQ' 'TEMPORAL DER'
#  'OCCIPITO-PARIETAL DER' 'OCCIPITAL DER' 'OCCIPITAL IZQ' 'PARIETOOCIPITAL'
#  'CEREBELO IZQ' 'CEREBELO DER' 'CEERBELO DER' 'ORBITARIA IZQ' 'PUENTE'
#  'FRONTOPARIETAL DER' 'TÁLAMO DER' 'TÁLAMO IZQ' 'VERMIS CEREBELOSO'
#  'PEDUNCULO SUP DER' 'ASTA POST VLI' 'INSULA' 'NUCLEOS DE LA BASE DER'
#  'NUCLEO DE LA BASE IZQ' 'TALAMO DER' 'INSULAR' 'HOLOCRANEO'
#  'ANGULO PONTOCEREBELOSO' 'CAUDADO DER' 'CAUDADO IZQ' 'VERMIS']

# %%
df_cleaned['LOCALIZACIÓN'] = df_cleaned['LOCALIZACIÓN'].replace({
    'PARIETAL IZQ': 'PARIETAL', 'PARIETAL DER': 'PARIETAL',
    'FRONTAL DER': 'FRONTAL', 'FRONTAL IZQ': 'FRONTAL',
    'CEREBELO IZQ': 'CEREBELO', 'CEREBELO DER': 'CEREBELO', 'CEERBELO DER': 'CEREBELO',
    'TEMPORAL IZQ': 'TEMPORAL', 'TEMPORAL DER': 'TEMPORAL',
    'INSULA': 'INSULAR', 'TÁLAMO DER': 'TÁLAMO', 'TÁLAMO IZQ': 'TÁLAMO',
    'CAUDADO DER': 'CAUDADO', 'CAUDADO IZQ': 'CAUDADO',
    'OCCIPITAL DER': 'OCCIPITAL', 'OCCIPITAL IZQ': 'OCCIPITAL',
    'OCCIPITO-PARIETAL DER': 'PARIETOOCIPITAL',
    'NUCLEOS DE LA BASE DER': 'NUCLEOS DE LA BASE',
    'NUCLEO DE LA BASE IZQ': 'NUCLEOS DE LA BASE',
    'TÁLAMO DER': 'TÁLAMO', 'TÁLAMO IZQ': 'TÁLAMO',
    'TALAMO DER': 'TÁLAMO', 'ORBITARIA IZQ': 'ÓRBITA IZQ',
    'VERMIS': 'VERMIS CEREBELOSO',

}, regex=False)

# %%
# Crear tabla de contingencia
contingency_table = pd.crosstab(df_cleaned['TUMOR PRIMARIO'], df_cleaned['LOCALIZACIÓN'])

# Realizar prueba chi-cuadrado
chi2, p_value, dof, expected = stats.chi2_contingency(contingency_table)

print('\nResultados del Test Chi-cuadrado:')
print(f'Estadístico Chi2: {chi2:.4f}')
print(f'Valor p: {p_value:.4f}')
print('\nTabla de contingencia:')
print(contingency_table)

# Crear un heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(contingency_table, annot=True, cmap='YlOrRd', fmt='d')
plt.title('Relación entre Tumor Primario y Localización')
plt.xlabel('Localización')
plt.ylabel('Tumor Primario')
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.yticks(rotation=0, fontsize=8)
plt.tight_layout()
plt.show()
# Out:
# Resultados del Test Chi-cuadrado:
# Estadístico Chi2: 477.4825
# Valor p: 0.0000
#
# Tabla de contingencia:
# LOCALIZACIÓN            ANGULO PONTOCEREBELOSO  ASTA POST VLI  CAUDADO  \
# TUMOR PRIMARIO
# CÁNCER CERVICOUTERINO                        0              0        0
# CÁNCER DE COLON                              0              0        0
# CÁNCER DE ENDOMETRIO                         0              0        0
# CÁNCER DE ESOFAGO                            0              0        0
# CÁNCER DE MAMA                               0              0        0
# CÁNCER DE OVARIO                             0              0        0
# CÁNCER DE PRÓSTATA                           0              0        0
# CÁNCER DE PULMÓN                             0              0        2
# CÁNCER DE TIROIDES                           0              0        0
# CÁNCER RENAL                                 0              1        0
# CÁNCER TESTICULAR                            0              0        0
# MELANOMA                                     1              0        0
# TUMOR NEUROECTODÉRMICO                       0              0        0
# TUMOR NEUROENDOCRINO                         0              0        0
# Unknown                                      0              0        0
#
# LOCALIZACIÓN            CEREBELO  FRONTAL  FRONTOPARIETAL DER  HOLOCRANEO  \
# TUMOR PRIMARIO
# CÁNCER CERVICOUTERINO          0        0                   0           0
# CÁNCER DE COLON                0        0                   0           0
# CÁNCER DE ENDOMETRIO           1        5                   0           0
# CÁNCER DE ESOFAGO              0        0                   0           0
# CÁNCER DE MAMA                50       32                   0           1
# CÁNCER DE OVARIO               6        3                   0           0
# CÁNCER DE PRÓSTATA             0        1                   0           0
# CÁNCER DE PULMÓN              22       36                   0           0
# CÁNCER DE TIROIDES             5       14                   0           0
# CÁNCER RENAL                   7        9                   0           0
# CÁNCER TESTICULAR              1        1                   0           0
# MELANOMA                       0        2                   1           0
# TUMOR NEUROECTODÉRMICO         0        1                   0           0
# TUMOR NEUROENDOCRINO           3        0                   0           0
# Unknown                        1        0                   0           0
#
# LOCALIZACIÓN            INSULAR  MESENCÉFALO  NUCLEOS DE LA BASE  OCCIPITAL  \
# TUMOR PRIMARIO
# CÁNCER CERVICOUTERINO         0            0                   0          0
# CÁNCER DE COLON               0            0                   0          1
# CÁNCER DE ENDOMETRIO          0            0                   0          0
# CÁNCER DE ESOFAGO             0            0                   0          1
# CÁNCER DE MAMA                0            4                   0         42
# CÁNCER DE OVARIO              0            0                   0          2
# CÁNCER DE PRÓSTATA            0            0                   0          0
# CÁNCER DE PULMÓN              2            0                   3         25
# CÁNCER DE TIROIDES            0            0                   0          4
# CÁNCER RENAL                  0            0                   0          3
# CÁNCER TESTICULAR             0            0                   0          0
# MELANOMA                      0            0                   0          7
# TUMOR NEUROECTODÉRMICO        0            0                   0          0
# TUMOR NEUROENDOCRINO          0            0                   0          3
# Unknown                       0            0                   0          0
#
# LOCALIZACIÓN            PARIETAL  PARIETOOCIPITAL  PEDUNCULO SUP DER  PUENTE  \
# TUMOR PRIMARIO
# CÁNCER CERVICOUTERINO          0                1                  0       0
# CÁNCER DE COLON                0                0                  0       0
# CÁNCER DE ENDOMETRIO           1                0                  0       0
# CÁNCER DE ESOFAGO              0                0                  0       0
# CÁNCER DE MAMA                32                1                  1       2
# CÁNCER DE OVARIO               5                0                  0       0
# CÁNCER DE PRÓSTATA             0                0                  0       0
# CÁNCER DE PULMÓN              34                0                  0       1
# CÁNCER DE TIROIDES             8                0                  0       0
# CÁNCER RENAL                   4                0                  0       1
# CÁNCER TESTICULAR              1                0                  0       0
# MELANOMA                       5                0                  0       0
# TUMOR NEUROECTODÉRMICO         1                0                  0       0
# TUMOR NEUROENDOCRINO           6                0                  0       0
# Unknown                        0                0                  0       0
#
# LOCALIZACIÓN            TEMPORAL  TENTORIAL  TÁLAMO  VERMIS CEREBELOSO  \
# TUMOR PRIMARIO
# CÁNCER CERVICOUTERINO          0          0       0                  0
# CÁNCER DE COLON                0          0       0                  0
# CÁNCER DE ENDOMETRIO           0          0       0                  0
# CÁNCER DE ESOFAGO              1          0       0                  0
# CÁNCER DE MAMA                14          1       3                  1
# CÁNCER DE OVARIO               0          0       0                  0
# CÁNCER DE PRÓSTATA             0          0       0                  0
# CÁNCER DE PULMÓN              21          0       2                  1
# CÁNCER DE TIROIDES             7          0       0                  0
# CÁNCER RENAL                   0          0       0                  0
# CÁNCER TESTICULAR              0          0       0                  0
# MELANOMA                       1          0       0                  0
# TUMOR NEUROECTODÉRMICO         1          0       0                  0
# TUMOR NEUROENDOCRINO           4          0       0                  0
# Unknown                        0          0       0                  0
#
# LOCALIZACIÓN            ÓRBITA IZQ
# TUMOR PRIMARIO
# CÁNCER CERVICOUTERINO            0
# CÁNCER DE COLON                  0
# CÁNCER DE ENDOMETRIO             0
# CÁNCER DE ESOFAGO                0
# CÁNCER DE MAMA                   1
# CÁNCER DE OVARIO                 0
# CÁNCER DE PRÓSTATA               0
# CÁNCER DE PULMÓN                 0
# CÁNCER DE TIROIDES               0
# CÁNCER RENAL                     0
# CÁNCER TESTICULAR                0
# MELANOMA                         0
# TUMOR NEUROECTODÉRMICO           1
# TUMOR NEUROENDOCRINO             0
# Unknown                          0

# %% [markdown]
# El estadístico chi-cuadrado obtenido fue de 1242.1673 con un valor p < 0.05. Esto indica una relación estadísticamente significativa entre el tipo de tumor primario y la localización de la metástasis. Es decir, el tipo de tumor primario influye en la localización de la metástasis.
#
# Encontramos principalmente una relación de tumor primario en mama con la localización en lóbulo occipital, lóbulo parietal, lóbulo frontal y cerebelo.
# Además, otra relación importante es entre tumor primario en pulmón y localización en lóbulo frontal (con ayor incidencia en lóbulo frontal derecho respecto al izquierdo), lóbulo parietal, lóbulo occipital, lóbulo temporal y cerebelo.
